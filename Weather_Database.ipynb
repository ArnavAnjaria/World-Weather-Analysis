# %% [markdown]
# ### Imports

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %% [markdown]
# ### Get Random Coordinates

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %% [markdown]
# ### Get the cities from the coordinates

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 735

# %% [markdown]
# ### Get the required weather data from OpenWatherMap using the API calls
#
# Data Needed:
# - Latitude and longitude
# - Maximum temperature
# - Percent humidity
# - Percent cloudiness
# - Wind speed
# - Weather description (for example, clouds, fog, light rain, clear sky)

# %%
# Import the requests library.
import requests
# Import the API key.
from config import weather_api_key
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        # time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | chernyshevskiy
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | beeville
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | beloha
# Processing Record 7 of Set 1 | nalut
# Processing Record 8 of Set 1 | bethel
# Processing Record 9 of Set 1 | ponta do sol
# Processing Record 10 of Set 1 | casalmaggiore
# Processing Record 11 of Set 1 | haines junction
# Processing Record 12 of Set 1 | port hedland
# Processing Record 13 of Set 1 | saint george
# Processing Record 14 of Set 1 | tuktoyaktuk
# Processing Record 15 of Set 1 | santander
# Processing Record 16 of Set 1 | knokke-heist
# Processing Record 17 of Set 1 | chaa-khol
# City not found. Skipping...
# Processing Record 18 of Set 1 | clyde river
# Processing Record 19 of Set 1 | north bend
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | upernavik
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | namie
# Processing Record 26 of Set 1 | macia
# Processing Record 27 of Set 1 | puerto ayora
# Processing Record 28 of Set 1 | hualmay
# Processing Record 29 of Set 1 | chuy
# Processing Record 30 of Set 1 | victoria
# Processing Record 31 of Set 1 | touros
# Processing Record 32 of Set 1 | costa rica
# Processing Record 33 of Set 1 | vaini
# Processing Record 34 of Set 1 | skagastrond
# City not found. Skipping...
# Processing Record 35 of Set 1 | voh
# Processing Record 36 of Set 1 | kruisfontein
# Processing Record 37 of Set 1 | rapid city
# Processing Record 38 of Set 1 | faanui
# Processing Record 39 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 1 | albany
# Processing Record 42 of Set 1 | port elizabeth
# Processing Record 43 of Set 1 | hermanus
# Processing Record 44 of Set 1 | cherskiy
# Processing Record 45 of Set 1 | hofn
# Processing Record 46 of Set 1 | torbay
# Processing Record 47 of Set 1 | bluff
# Processing Record 48 of Set 1 | corrente
# Processing Record 49 of Set 1 | natal
# Processing Record 50 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 2 | hilo
# Processing Record 2 of Set 2 | qaanaaq
# Processing Record 3 of Set 2 | pilar
# Processing Record 4 of Set 2 | la maddalena
# Processing Record 5 of Set 2 | pacific grove
# Processing Record 6 of Set 2 | barrow
# Processing Record 7 of Set 2 | avarua
# Processing Record 8 of Set 2 | kushima
# Processing Record 9 of Set 2 | berlevag
# Processing Record 10 of Set 2 | asau
# Processing Record 11 of Set 2 | kodiak
# Processing Record 12 of Set 2 | busselton
# Processing Record 13 of Set 2 | butaritari
# Processing Record 14 of Set 2 | dukat
# Processing Record 15 of Set 2 | tashtyp
# Processing Record 16 of Set 2 | mataura
# Processing Record 17 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 2 | eldorado
# Processing Record 19 of Set 2 | garmsar
# Processing Record 20 of Set 2 | eureka
# Processing Record 21 of Set 2 | klaksvik
# Processing Record 22 of Set 2 | dunedin
# Processing Record 23 of Set 2 | tiksi
# Processing Record 24 of Set 2 | taywarah
# Processing Record 25 of Set 2 | puerto escondido
# Processing Record 26 of Set 2 | narsaq
# Processing Record 27 of Set 2 | quatre cocos
# Processing Record 28 of Set 2 | arraial do cabo
# Processing Record 29 of Set 2 | sao joao da barra
# Processing Record 30 of Set 2 | vila franca do campo
# Processing Record 31 of Set 2 | ribeira grande
# Processing Record 32 of Set 2 | hithadhoo
# Processing Record 33 of Set 2 | nikolskoye
# Processing Record 34 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 2 | aasmae
# City not found. Skipping...
# Processing Record 36 of Set 2 | bedesa
# Processing Record 37 of Set 2 | mago
# Processing Record 38 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 2 | janauba
# Processing Record 41 of Set 2 | khatanga
# Processing Record 42 of Set 2 | saint-philippe
# Processing Record 43 of Set 2 | balabac
# Processing Record 44 of Set 2 | castro
# Processing Record 45 of Set 2 | chokurdakh
# Processing Record 46 of Set 2 | walvis bay
# Processing Record 47 of Set 2 | norman wells
# Processing Record 48 of Set 2 | zhanatas
# City not found. Skipping...
# Processing Record 49 of Set 2 | vestmannaeyjar
# Processing Record 50 of Set 2 | new norfolk
# Processing Record 1 of Set 3 | yaqui
# Processing Record 2 of Set 3 | aklavik
# Processing Record 3 of Set 3 | caravelas
# Processing Record 4 of Set 3 | labuhan
# Processing Record 5 of Set 3 | kapaa
# Processing Record 6 of Set 3 | oranjemund
# Processing Record 7 of Set 3 | muzquiz
# City not found. Skipping...
# Processing Record 8 of Set 3 | ossora
# Processing Record 9 of Set 3 | provideniya
# Processing Record 10 of Set 3 | ilulissat
# Processing Record 11 of Set 3 | husavik
# Processing Record 12 of Set 3 | yellowknife
# Processing Record 13 of Set 3 | sola
# Processing Record 14 of Set 3 | san patricio
# Processing Record 15 of Set 3 | hanko
# Processing Record 16 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 3 | yar-sale
# Processing Record 18 of Set 3 | ribeira brava
# Processing Record 19 of Set 3 | hvide sande
# Processing Record 20 of Set 3 | bara
# Processing Record 21 of Set 3 | asyut
# Processing Record 22 of Set 3 | port alfred
# Processing Record 23 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 3 | torres
# Processing Record 25 of Set 3 | pisco
# Processing Record 26 of Set 3 | thompson
# Processing Record 27 of Set 3 | zonguldak
# Processing Record 28 of Set 3 | grand-santi
# Processing Record 29 of Set 3 | esperance
# Processing Record 30 of Set 3 | sabha
# Processing Record 31 of Set 3 | east london
# Processing Record 32 of Set 3 | coihaique
# Processing Record 33 of Set 3 | ostrovnoy
# Processing Record 34 of Set 3 | tubruq
# City not found. Skipping...
# Processing Record 35 of Set 3 | opuwo
# Processing Record 36 of Set 3 | kavieng
# Processing Record 37 of Set 3 | harwich
# Processing Record 38 of Set 3 | martinsburg
# Processing Record 39 of Set 3 | mocajuba
# Processing Record 40 of Set 3 | tasbuget
# City not found. Skipping...
# Processing Record 41 of Set 3 | jamestown
# Processing Record 42 of Set 3 | pervomayskiy
# Processing Record 43 of Set 3 | maniitsoq
# Processing Record 44 of Set 3 | vicuna
# Processing Record 45 of Set 3 | saldanha
# Processing Record 46 of Set 3 | alihe
# Processing Record 47 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 3 | naze
# Processing Record 50 of Set 3 | sindor
# Processing Record 1 of Set 4 | longyearbyen
# Processing Record 2 of Set 4 | barcelos
# Processing Record 3 of Set 4 | weligama
# Processing Record 4 of Set 4 | raudeberg
# Processing Record 5 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 4 | tasiilaq
# Processing Record 7 of Set 4 | leningradskiy
# Processing Record 8 of Set 4 | porto velho
# Processing Record 9 of Set 4 | katete
# Processing Record 10 of Set 4 | laguna
# Processing Record 11 of Set 4 | kirovskiy
# Processing Record 12 of Set 4 | port-gentil
# Processing Record 13 of Set 4 | hervey bay
# Processing Record 14 of Set 4 | bengkulu
# Processing Record 15 of Set 4 | tabou
# Processing Record 16 of Set 4 | oulainen
# Processing Record 17 of Set 4 | myitkyina
# Processing Record 18 of Set 4 | saint anthony
# Processing Record 19 of Set 4 | san jeronimo
# Processing Record 20 of Set 4 | cervo
# Processing Record 21 of Set 4 | buariki
# City not found. Skipping...
# Processing Record 22 of Set 4 | kalutara
# Processing Record 23 of Set 4 | margate
# Processing Record 24 of Set 4 | poum
# Processing Record 25 of Set 4 | kavaratti
# Processing Record 26 of Set 4 | verkhoyansk
# Processing Record 27 of Set 4 | padang
# Processing Record 28 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 29 of Set 4 | san miguel de cauri
# Processing Record 30 of Set 4 | adre
# Processing Record 31 of Set 4 | mahebourg
# Processing Record 32 of Set 4 | joshimath
# Processing Record 33 of Set 4 | mar del plata
# Processing Record 34 of Set 4 | boende
# Processing Record 35 of Set 4 | tawkar
# City not found. Skipping...
# Processing Record 36 of Set 4 | grand gaube
# Processing Record 37 of Set 4 | mombetsu
# Processing Record 38 of Set 4 | ternate
# Processing Record 39 of Set 4 | pangnirtung
# Processing Record 40 of Set 4 | cidreira
# Processing Record 41 of Set 4 | kuito
# Processing Record 42 of Set 4 | sur
# Processing Record 43 of Set 4 | combita
# Processing Record 44 of Set 4 | cururupu
# Processing Record 45 of Set 4 | port lincoln
# Processing Record 46 of Set 4 | airai
# Processing Record 47 of Set 4 | iberia
# Processing Record 48 of Set 4 | nioro
# Processing Record 49 of Set 4 | fortuna
# Processing Record 50 of Set 4 | port blair
# Processing Record 1 of Set 5 | quang ngai
# Processing Record 2 of Set 5 | merauke
# Processing Record 3 of Set 5 | carnarvon
# Processing Record 4 of Set 5 | talnakh
# Processing Record 5 of Set 5 | kaseda
# Processing Record 6 of Set 5 | cabo san lucas
# Processing Record 7 of Set 5 | nouadhibou
# Processing Record 8 of Set 5 | qorveh
# Processing Record 9 of Set 5 | sechura
# Processing Record 10 of Set 5 | marsaxlokk
# Processing Record 11 of Set 5 | tungkang
# City not found. Skipping...
# Processing Record 12 of Set 5 | westport
# Processing Record 13 of Set 5 | bathsheba
# Processing Record 14 of Set 5 | tuatapere
# Processing Record 15 of Set 5 | kaitangata
# Processing Record 16 of Set 5 | mount gambier
# Processing Record 17 of Set 5 | umm lajj
# Processing Record 18 of Set 5 | aktau
# Processing Record 19 of Set 5 | killybegs
# Processing Record 20 of Set 5 | hambantota
# Processing Record 21 of Set 5 | cayenne
# Processing Record 22 of Set 5 | freeport
# Processing Record 23 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 24 of Set 5 | bambous virieux
# Processing Record 25 of Set 5 | moroni
# Processing Record 26 of Set 5 | dandong
# Processing Record 27 of Set 5 | ust-nera
# Processing Record 28 of Set 5 | albacete
# Processing Record 29 of Set 5 | ponta delgada
# Processing Record 30 of Set 5 | thinadhoo
# Processing Record 31 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 5 | ascension
# Processing Record 33 of Set 5 | nandgaon
# Processing Record 34 of Set 5 | emerald
# Processing Record 35 of Set 5 | novopavlovka
# Processing Record 36 of Set 5 | latung
# Processing Record 37 of Set 5 | los llanos de aridane
# Processing Record 38 of Set 5 | moberly
# Processing Record 39 of Set 5 | tingi
# Processing Record 40 of Set 5 | soyo
# Processing Record 41 of Set 5 | camopi
# Processing Record 42 of Set 5 | severo-kurilsk
# Processing Record 43 of Set 5 | tooele
# Processing Record 44 of Set 5 | terralba
# Processing Record 45 of Set 5 | olga
# Processing Record 46 of Set 5 | georgetown
# Processing Record 47 of Set 5 | lebu
# Processing Record 48 of Set 5 | mangrol
# Processing Record 49 of Set 5 | tecoanapa
# Processing Record 50 of Set 5 | comodoro rivadavia
# Processing Record 1 of Set 6 | luderitz
# Processing Record 2 of Set 6 | guerrero negro
# Processing Record 3 of Set 6 | takoradi
# Processing Record 4 of Set 6 | bielsk podlaski
# Processing Record 5 of Set 6 | svetlaya
# Processing Record 6 of Set 6 | souillac
# Processing Record 7 of Set 6 | egvekinot
# Processing Record 8 of Set 6 | havoysund
# Processing Record 9 of Set 6 | flinders
# Processing Record 10 of Set 6 | luis correia
# Processing Record 11 of Set 6 | bubaque
# Processing Record 12 of Set 6 | constitucion
# Processing Record 13 of Set 6 | puerto leguizamo
# Processing Record 14 of Set 6 | victoria point
# Processing Record 15 of Set 6 | kiruna
# Processing Record 16 of Set 6 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 17 of Set 6 | saint-donat-de-montcalm
# Processing Record 18 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 19 of Set 6 | broken hill
# Processing Record 20 of Set 6 | kokopo
# Processing Record 21 of Set 6 | salalah
# Processing Record 22 of Set 6 | vardo
# Processing Record 23 of Set 6 | were ilu
# Processing Record 24 of Set 6 | iqaluit
# Processing Record 25 of Set 6 | tautira
# Processing Record 26 of Set 6 | boyolangu
# Processing Record 27 of Set 6 | kalanchak
# Processing Record 28 of Set 6 | sfantu gheorghe
# Processing Record 29 of Set 6 | buala
# Processing Record 30 of Set 6 | rawson
# Processing Record 31 of Set 6 | andenes
# Processing Record 32 of Set 6 | digby
# Processing Record 33 of Set 6 | lahij
# Processing Record 34 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 35 of Set 6 | korem
# Processing Record 36 of Set 6 | port augusta
# Processing Record 37 of Set 6 | ust-kuyga
# Processing Record 38 of Set 6 | vilyuysk
# Processing Record 39 of Set 6 | balimo
# City not found. Skipping...
# Processing Record 40 of Set 6 | dongsheng
# Processing Record 41 of Set 6 | greenville
# Processing Record 42 of Set 6 | nyurba
# Processing Record 43 of Set 6 | jumla
# Processing Record 44 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 45 of Set 6 | carutapera
# Processing Record 46 of Set 6 | geraldton
# Processing Record 47 of Set 6 | murgab
# Processing Record 48 of Set 6 | shingu
# Processing Record 49 of Set 6 | la rioja
# Processing Record 50 of Set 6 | tilichiki
# Processing Record 1 of Set 7 | nishihara
# Processing Record 2 of Set 7 | aden
# Processing Record 3 of Set 7 | gao
# Processing Record 4 of Set 7 | lorengau
# Processing Record 5 of Set 7 | portland
# Processing Record 6 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 7 of Set 7 | matadi
# Processing Record 8 of Set 7 | sakaiminato
# Processing Record 9 of Set 7 | fort nelson
# Processing Record 10 of Set 7 | nicoya
# Processing Record 11 of Set 7 | rawah
# Processing Record 12 of Set 7 | lavrentiya
# Processing Record 13 of Set 7 | port-cartier
# Processing Record 14 of Set 7 | bellevue
# Processing Record 15 of Set 7 | colares
# Processing Record 16 of Set 7 | rio grande
# Processing Record 17 of Set 7 | sao lourenco do oeste
# Processing Record 18 of Set 7 | macaboboni
# City not found. Skipping...
# Processing Record 19 of Set 7 | gonbad-e qabus
# Processing Record 20 of Set 7 | atikokan
# Processing Record 21 of Set 7 | sisimiut
# Processing Record 22 of Set 7 | yandoon
# City not found. Skipping...
# Processing Record 23 of Set 7 | mezen
# Processing Record 24 of Set 7 | zhangjiakou
# Processing Record 25 of Set 7 | ojinaga
# Processing Record 26 of Set 7 | harper
# Processing Record 27 of Set 7 | wanning
# Processing Record 28 of Set 7 | korla
# Processing Record 29 of Set 7 | ewa beach
# Processing Record 30 of Set 7 | solnechnyy
# Processing Record 31 of Set 7 | manggar
# Processing Record 32 of Set 7 | codrington
# Processing Record 33 of Set 7 | la paz
# Processing Record 34 of Set 7 | lagoa
# Processing Record 35 of Set 7 | marystown
# Processing Record 36 of Set 7 | tyup
# Processing Record 37 of Set 7 | wulanhaote
# City not found. Skipping...
# Processing Record 38 of Set 7 | beringovskiy
# Processing Record 39 of Set 7 | belchatow
# Processing Record 40 of Set 7 | eyemouth
# Processing Record 41 of Set 7 | nanortalik
# Processing Record 42 of Set 7 | atlantis
# Processing Record 43 of Set 7 | vestmanna
# Processing Record 44 of Set 7 | humaita
# Processing Record 45 of Set 7 | acapulco
# Processing Record 46 of Set 7 | hami
# Processing Record 47 of Set 7 | praia
# Processing Record 48 of Set 7 | ancud
# Processing Record 49 of Set 7 | pevek
# Processing Record 50 of Set 7 | ambon
# Processing Record 1 of Set 8 | ubinskoye
# Processing Record 2 of Set 8 | saskylakh
# Processing Record 3 of Set 8 | gigmoto
# Processing Record 4 of Set 8 | shagonar
# Processing Record 5 of Set 8 | mwense
# Processing Record 6 of Set 8 | dikson
# Processing Record 7 of Set 8 | camacha
# Processing Record 8 of Set 8 | jaguarari
# Processing Record 9 of Set 8 | krasnoselkup
# Processing Record 10 of Set 8 | lilongwe
# Processing Record 11 of Set 8 | santana do acarau
# Processing Record 12 of Set 8 | letlhakane
# Processing Record 13 of Set 8 | buenaventura
# Processing Record 14 of Set 8 | pingliang
# Processing Record 15 of Set 8 | nieuw amsterdam
# Processing Record 16 of Set 8 | la ronge
# Processing Record 17 of Set 8 | shkotovo-26
# City not found. Skipping...
# Processing Record 18 of Set 8 | kuzino
# Processing Record 19 of Set 8 | nizwa
# Processing Record 20 of Set 8 | wanaka
# Processing Record 21 of Set 8 | vaitape
# Processing Record 22 of Set 8 | shafter
# Processing Record 23 of Set 8 | muriae
# Processing Record 24 of Set 8 | lages
# Processing Record 25 of Set 8 | kurkino
# Processing Record 26 of Set 8 | talcahuano
# Processing Record 27 of Set 8 | omboue
# Processing Record 28 of Set 8 | tigil
# Processing Record 29 of Set 8 | lokosovo
# Processing Record 30 of Set 8 | mercedes
# Processing Record 31 of Set 8 | gat
# Processing Record 32 of Set 8 | lodja
# Processing Record 33 of Set 8 | horodyshche
# Processing Record 34 of Set 8 | erzin
# Processing Record 35 of Set 8 | araouane
# Processing Record 36 of Set 8 | la grande
# Processing Record 37 of Set 8 | sept-iles
# Processing Record 38 of Set 8 | namuac
# Processing Record 39 of Set 8 | plettenberg bay
# Processing Record 40 of Set 8 | alofi
# Processing Record 41 of Set 8 | mackay
# Processing Record 42 of Set 8 | arlit
# Processing Record 43 of Set 8 | inirida
# Processing Record 44 of Set 8 | san ramon
# Processing Record 45 of Set 8 | ngunguru
# Processing Record 46 of Set 8 | kaduy
# Processing Record 47 of Set 8 | namibe
# Processing Record 48 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 49 of Set 8 | dali
# Processing Record 50 of Set 8 | pinawa
# Processing Record 1 of Set 9 | mecca
# Processing Record 2 of Set 9 | ndele
# Processing Record 3 of Set 9 | shurugwi
# Processing Record 4 of Set 9 | zomin
# Processing Record 5 of Set 9 | houston
# Processing Record 6 of Set 9 | kaka
# Processing Record 7 of Set 9 | college
# Processing Record 8 of Set 9 | yining
# Processing Record 9 of Set 9 | monrovia
# Processing Record 10 of Set 9 | ahipara
# Processing Record 11 of Set 9 | ishigaki
# Processing Record 12 of Set 9 | bundaberg
# Processing Record 13 of Set 9 | ormara
# Processing Record 14 of Set 9 | dharangaon
# Processing Record 15 of Set 9 | rosetta
# Processing Record 16 of Set 9 | vitim
# Processing Record 17 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 18 of Set 9 | mpika
# Processing Record 19 of Set 9 | monteagudo
# Processing Record 20 of Set 9 | saint-georges
# Processing Record 21 of Set 9 | jawhar
# Processing Record 22 of Set 9 | quelimane
# Processing Record 23 of Set 9 | moose factory
# Processing Record 24 of Set 9 | sidrolandia
# Processing Record 25 of Set 9 | inhambane
# Processing Record 26 of Set 9 | puerto ayacucho
# Processing Record 27 of Set 9 | uvira
# Processing Record 28 of Set 9 | tyukhtet
# Processing Record 29 of Set 9 | belmonte
# Processing Record 30 of Set 9 | turukhansk
# Processing Record 31 of Set 9 | hastings
# Processing Record 32 of Set 9 | paamiut
# Processing Record 33 of Set 9 | salvador
# Processing Record 34 of Set 9 | san andres
# Processing Record 35 of Set 9 | khorinsk
# Processing Record 36 of Set 9 | peterhead
# Processing Record 37 of Set 9 | lompoc
# Processing Record 38 of Set 9 | shakawe
# Processing Record 39 of Set 9 | dicabisagan
# Processing Record 40 of Set 9 | toyooka
# Processing Record 41 of Set 9 | monticello
# Processing Record 42 of Set 9 | cartagena
# Processing Record 43 of Set 9 | manavalakurichi
# Processing Record 44 of Set 9 | rathdrum
# Processing Record 45 of Set 9 | chapleau
# Processing Record 46 of Set 9 | susanville
# Processing Record 47 of Set 9 | nome
# Processing Record 48 of Set 9 | tarpon springs
# Processing Record 49 of Set 9 | maues
# Processing Record 50 of Set 9 | bom jesus da lapa
# Processing Record 1 of Set 10 | wapi pathum
# Processing Record 2 of Set 10 | bereda
# Processing Record 3 of Set 10 | jaciara
# Processing Record 4 of Set 10 | aykhal
# Processing Record 5 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 6 of Set 10 | tomatlan
# Processing Record 7 of Set 10 | tura
# Processing Record 8 of Set 10 | desnogorsk
# Processing Record 9 of Set 10 | shimoda
# Processing Record 10 of Set 10 | darnah
# Processing Record 11 of Set 10 | ballina
# Processing Record 12 of Set 10 | woodward
# Processing Record 13 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 10 | taraz
# Processing Record 15 of Set 10 | yetholm
# City not found. Skipping...
# Processing Record 16 of Set 10 | flin flon
# Processing Record 17 of Set 10 | christchurch
# Processing Record 18 of Set 10 | pochutla
# Processing Record 19 of Set 10 | lazaro cardenas
# Processing Record 20 of Set 10 | komagane
# Processing Record 21 of Set 10 | moindou
# Processing Record 22 of Set 10 | taltal
# Processing Record 23 of Set 10 | roald
# Processing Record 24 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 25 of Set 10 | waitati
# Processing Record 26 of Set 10 | nemuro
# Processing Record 27 of Set 10 | yarmouth
# Processing Record 28 of Set 10 | santa cruz
# Processing Record 29 of Set 10 | puerto narino
# Processing Record 30 of Set 10 | suntar
# Processing Record 31 of Set 10 | silver city
# Processing Record 32 of Set 10 | sitka
# Processing Record 33 of Set 10 | port keats
# Processing Record 34 of Set 10 | okhotsk
# Processing Record 35 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 10 | tambura
# Processing Record 37 of Set 10 | lindi
# Processing Record 38 of Set 10 | fare
# Processing Record 39 of Set 10 | gasa
# Processing Record 40 of Set 10 | wittstock
# Processing Record 41 of Set 10 | itaobim
# Processing Record 42 of Set 10 | gazimurskiy zavod
# Processing Record 43 of Set 10 | zemio
# Processing Record 44 of Set 10 | olafsvik
# Processing Record 45 of Set 10 | kutum
# Processing Record 46 of Set 10 | coahuayana
# Processing Record 47 of Set 10 | mbanza-ngungu
# Processing Record 48 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 49 of Set 10 | srednekolymsk
# Processing Record 50 of Set 10 | washougal
# Processing Record 1 of Set 11 | umm durman
# City not found. Skipping...
# Processing Record 2 of Set 11 | nabire
# Processing Record 3 of Set 11 | kenai
# Processing Record 4 of Set 11 | sena madureira
# Processing Record 5 of Set 11 | richards bay
# Processing Record 6 of Set 11 | bahia blanca
# Processing Record 7 of Set 11 | tanabe
# Processing Record 8 of Set 11 | castlebar
# Processing Record 9 of Set 11 | tual
# Processing Record 10 of Set 11 | lasa
# Processing Record 11 of Set 11 | severodvinsk
# Processing Record 12 of Set 11 | usinsk
# Processing Record 13 of Set 11 | gladstone
# Processing Record 14 of Set 11 | russell
# Processing Record 15 of Set 11 | rio gallegos
# Processing Record 16 of Set 11 | praia da vitoria
# Processing Record 17 of Set 11 | damghan
# Processing Record 18 of Set 11 | bonthe
# Processing Record 19 of Set 11 | caxito
# Processing Record 20 of Set 11 | ayan
# Processing Record 21 of Set 11 | elizabeth city
# Processing Record 22 of Set 11 | nsanje
# Processing Record 23 of Set 11 | anar darreh
# City not found. Skipping...
# Processing Record 24 of Set 11 | darlawn
# Processing Record 25 of Set 11 | teya
# Processing Record 26 of Set 11 | kaeo
# Processing Record 27 of Set 11 | chifeng
# Processing Record 28 of Set 11 | glenwood springs
# Processing Record 29 of Set 11 | inta
# Processing Record 30 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 31 of Set 11 | tessalit
# Processing Record 32 of Set 11 | suluq
# Processing Record 33 of Set 11 | bilibino
# Processing Record 34 of Set 11 | changzhou
# Processing Record 35 of Set 11 | ixtapa
# Processing Record 36 of Set 11 | broome
# Processing Record 37 of Set 11 | pyaozerskiy
# Processing Record 38 of Set 11 | rocha
# Processing Record 39 of Set 11 | matias olimpio
# Processing Record 40 of Set 11 | waw
# Processing Record 41 of Set 11 | chapais
# Processing Record 42 of Set 11 | san quintin
# Processing Record 43 of Set 11 | kindu
# Processing Record 44 of Set 11 | javanrud
# Processing Record 45 of Set 11 | morant bay
# Processing Record 46 of Set 11 | teguise
# Processing Record 47 of Set 11 | krasnoarmeyskiy
# Processing Record 48 of Set 11 | fushun
# Processing Record 49 of Set 11 | priiskovyy
# Processing Record 50 of Set 11 | alexandria
# Processing Record 1 of Set 12 | byron bay
# Processing Record 2 of Set 12 | mandalgovi
# Processing Record 3 of Set 12 | baghdad
# Processing Record 4 of Set 12 | brandon
# Processing Record 5 of Set 12 | junnar
# Processing Record 6 of Set 12 | nombre de dios
# Processing Record 7 of Set 12 | gazni
# City not found. Skipping...
# Processing Record 8 of Set 12 | tonantins
# Processing Record 9 of Set 12 | katsuura
# Processing Record 10 of Set 12 | nadadores
# Processing Record 11 of Set 12 | ulaangom
# Processing Record 12 of Set 12 | dongning
# Processing Record 13 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 14 of Set 12 | henties bay
# Processing Record 15 of Set 12 | mehriz
# Processing Record 16 of Set 12 | octeville
# Processing Record 17 of Set 12 | kampot
# Processing Record 18 of Set 12 | sudbury
# Processing Record 19 of Set 12 | lopatino
# Processing Record 20 of Set 12 | alotau
# City not found. Skipping...
# Processing Record 21 of Set 12 | maura
# Processing Record 22 of Set 12 | pauini
# Processing Record 23 of Set 12 | heishan
# Processing Record 24 of Set 12 | saravan
# Processing Record 25 of Set 12 | bokspits
# City not found. Skipping...
# Processing Record 26 of Set 12 | kangaatsiaq
# Processing Record 27 of Set 12 | homer
# Processing Record 28 of Set 12 | phek
# Processing Record 29 of Set 12 | agropoli
# Processing Record 30 of Set 12 | texarkana
# Processing Record 31 of Set 12 | tiznit
# Processing Record 32 of Set 12 | pontianak
# Processing Record 33 of Set 12 | zhitikara
# City not found. Skipping...
# Processing Record 34 of Set 12 | stoyba
# City not found. Skipping...
# Processing Record 35 of Set 12 | itoman
# Processing Record 36 of Set 12 | toledo
# Processing Record 37 of Set 12 | vostok
# Processing Record 38 of Set 12 | aguimes
# Processing Record 39 of Set 12 | halifax
# Processing Record 40 of Set 12 | wenling
# Processing Record 41 of Set 12 | lima
# Processing Record 42 of Set 12 | yulara
# Processing Record 43 of Set 12 | litovko
# Processing Record 44 of Set 12 | gazojak
# Processing Record 45 of Set 12 | hovd
# Processing Record 46 of Set 12 | aporawan
# City not found. Skipping...
# Processing Record 47 of Set 12 | saint-leu
# Processing Record 48 of Set 12 | atascadero
# Processing Record 49 of Set 12 | tezu
# Processing Record 50 of Set 12 | pulsano
# Processing Record 1 of Set 13 | imbituba
# Processing Record 2 of Set 13 | salisbury
# Processing Record 3 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 13 | komsomolskiy
# Processing Record 5 of Set 13 | qianguo
# Processing Record 6 of Set 13 | batagay-alyta
# Processing Record 7 of Set 13 | vuktyl
# Processing Record 8 of Set 13 | szczytno
# Processing Record 9 of Set 13 | abha
# Processing Record 10 of Set 13 | eenhana
# Processing Record 11 of Set 13 | te anau
# Processing Record 12 of Set 13 | sao filipe
# Processing Record 13 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 14 of Set 13 | pokhara
# Processing Record 15 of Set 13 | champerico
# Processing Record 16 of Set 13 | zhigansk
# Processing Record 17 of Set 13 | thomastown
# Processing Record 18 of Set 13 | seoul
# Processing Record 19 of Set 13 | batticaloa
# Processing Record 20 of Set 13 | dhaka
# Processing Record 21 of Set 13 | papar
# Processing Record 22 of Set 13 | hasaki
# Processing Record 23 of Set 13 | shakhtinsk
# Processing Record 24 of Set 13 | puerto colombia
# Processing Record 25 of Set 13 | horsham
# Processing Record 26 of Set 13 | pedraza
# Processing Record 27 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 28 of Set 13 | viedma
# Processing Record 29 of Set 13 | vanavara
# Processing Record 30 of Set 13 | birjand
# Processing Record 31 of Set 13 | goderich
# Processing Record 32 of Set 13 | jiazi
# Processing Record 33 of Set 13 | tazovskiy
# Processing Record 34 of Set 13 | hirara
# Processing Record 35 of Set 13 | baykit
# Processing Record 36 of Set 13 | meadow lake
# Processing Record 37 of Set 13 | sao felix do xingu
# Processing Record 38 of Set 13 | hay river
# Processing Record 39 of Set 13 | karratha
# Processing Record 40 of Set 13 | vilya
# Processing Record 41 of Set 13 | mount isa
# Processing Record 42 of Set 13 | springbok
# Processing Record 43 of Set 13 | sorland
# Processing Record 44 of Set 13 | khormuj
# City not found. Skipping...
# Processing Record 45 of Set 13 | kurumkan
# Processing Record 46 of Set 13 | safonovo
# Processing Record 47 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 48 of Set 13 | lakatoro
# Processing Record 49 of Set 13 | faya
# Processing Record 50 of Set 13 | marfino
# Processing Record 1 of Set 14 | mbini
# Processing Record 2 of Set 14 | sinnamary
# Processing Record 3 of Set 14 | buraydah
# Processing Record 4 of Set 14 | saskatoon
# Processing Record 5 of Set 14 | dzhebariki-khaya
# Processing Record 6 of Set 14 | palana
# Processing Record 7 of Set 14 | mumford
# Processing Record 8 of Set 14 | banda aceh
# Processing Record 9 of Set 14 | abu dhabi
# Processing Record 10 of Set 14 | angoche
# Processing Record 11 of Set 14 | parakou
# Processing Record 12 of Set 14 | vega de alatorre
# Processing Record 13 of Set 14 | kautokeino
# Processing Record 14 of Set 14 | dourbali
# Processing Record 15 of Set 14 | ilula
# Processing Record 16 of Set 14 | la peca
# Processing Record 17 of Set 14 | hoshangabad
# Processing Record 18 of Set 14 | dingle
# Processing Record 19 of Set 14 | nabinagar
# Processing Record 20 of Set 14 | garden city
# Processing Record 21 of Set 14 | maroantsetra
# Processing Record 22 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 23 of Set 14 | palmer
# Processing Record 24 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 25 of Set 14 | qianan
# Processing Record 26 of Set 14 | suratgarh
# Processing Record 27 of Set 14 | donskoye
# Processing Record 28 of Set 14 | arrecife
# Processing Record 29 of Set 14 | marienburg
# Processing Record 30 of Set 14 | atambua
# Processing Record 31 of Set 14 | hengshui
# Processing Record 32 of Set 14 | kimbe
# Processing Record 33 of Set 14 | arucas
# Processing Record 34 of Set 14 | parakai
# Processing Record 35 of Set 14 | seymchan
# Processing Record 36 of Set 14 | lipari
# Processing Record 37 of Set 14 | alice springs
# Processing Record 38 of Set 14 | huanren
# Processing Record 39 of Set 14 | angicos
# Processing Record 40 of Set 14 | yarada
# Processing Record 41 of Set 14 | turayf
# Processing Record 42 of Set 14 | taunggyi
# Processing Record 43 of Set 14 | tolmin
# Processing Record 44 of Set 14 | lar
# Processing Record 45 of Set 14 | qaqortoq
# Processing Record 46 of Set 14 | maldonado
# Processing Record 47 of Set 14 | sakakah
# Processing Record 48 of Set 14 | axim
# Processing Record 49 of Set 14 | saint-francois
# Processing Record 50 of Set 14 | nhulunbuy
# Processing Record 1 of Set 15 | benidorm
# Processing Record 2 of Set 15 | jensen beach
# Processing Record 3 of Set 15 | muros
# Processing Record 4 of Set 15 | tursunzoda
# Processing Record 5 of Set 15 | kharp
# Processing Record 6 of Set 15 | mareeba
# Processing Record 7 of Set 15 | uyuni
# Processing Record 8 of Set 15 | waipawa
# Processing Record 9 of Set 15 | moron
# Processing Record 10 of Set 15 | del rio
# Processing Record 11 of Set 15 | meulaboh
# Processing Record 12 of Set 15 | jahrom
# City not found. Skipping...
# Processing Record 13 of Set 15 | amga
# Processing Record 14 of Set 15 | taft
# Processing Record 15 of Set 15 | alta floresta
# Processing Record 16 of Set 15 | coolum beach
# Processing Record 17 of Set 15 | ohara
# Processing Record 18 of Set 15 | antalaha
# Processing Record 19 of Set 15 | rudbar
# Processing Record 20 of Set 15 | durban
# Processing Record 21 of Set 15 | sumbe
# Processing Record 22 of Set 15 | huarmey
# Processing Record 23 of Set 15 | hamilton
# Processing Record 24 of Set 15 | houma
# Processing Record 25 of Set 15 | trelew
# Processing Record 26 of Set 15 | saint-pierre
# Processing Record 27 of Set 15 | irbeyskoye
# Processing Record 28 of Set 15 | hobyo
# Processing Record 29 of Set 15 | kirkuk
# Processing Record 30 of Set 15 | kattivakkam
# Processing Record 31 of Set 15 | cap malheureux
# Processing Record 32 of Set 15 | kalamnuri
# Processing Record 33 of Set 15 | jalu
# Processing Record 34 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 35 of Set 15 | makakilo city
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Chernyshevskiy  63.0128  112.4714    -17.00       100         100
# 1          Hobart -42.8794  147.3294     62.28        86           0
# 2        Beeville  28.4008  -97.7483     87.35        54           1
# 3    Punta Arenas -53.1500  -70.9167     51.82        46          40
# 4          Atuona  -9.8000 -139.0333     78.04        77           8
# 5          Beloha -25.1667   45.0500     74.93        83          97
# 6           Nalut  30.3333   10.8500     53.51        65           0
# 7          Bethel  41.3712  -73.4140     51.89        86          90
# 8    Ponta Do Sol  32.6667  -17.1000     73.13        40          71
# 9   Casalmaggiore  44.9939   10.4189     54.39        85           3
#
#    Wind Speed Country                 Date
# 0        2.42      RU  2021-12-31 19:38:39
# 1        5.75      AU  2021-12-31 19:37:42
# 2       17.27      US  2021-12-31 19:38:40
# 3       29.93      CL  2021-12-31 19:38:40
# 4       15.88      PF  2021-12-31 19:38:40
# 5        9.35      MG  2021-12-31 19:38:41
# 6       10.20      LY  2021-12-31 19:38:41
# 7        4.61      US  2021-12-31 19:38:42
# 8        4.65      PT  2021-12-31 19:38:42
# 9        4.07      IT  2021-12-31 19:38:42

# %% [markdown]
# ### Output to CSV

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
